# %% [markdown]
# Tasks
# 1.
# Create a Python list representing the daily step count for a week (7 numbers), and explain why a sequence model like an RNN would be more suitable than a standard feedforward neural network for predicting tomorrow's steps.
# 2.
# Implement a simple RNN cell from scratch in Python that takes a sequence of 5 numbers (e.g., song play counts per day from Spotify) and outputs the final hidden state after processing the sequence.<br><br><em><strong>Hint:</strong> Use the formula: h_t = tanh(Wx_t + Uh_{t-1} + b), where h_0 = 0.</em>
# 3.
# Given the following sentence: 'I love cricket and IPL matches', convert each word to a unique integer (word-to-index mapping), then simulate how an RNN would process this sequence by updating and printing the hidden state at each step.
# 4.
# Explain the vanishing gradient problem in RNNs using your own words, and give one real-world example (from text, speech, or time-series apps) where this issue might cause poor predictions.
# 5.
# Use ChatGPT to generate a short Python code snippet that demonstrates Backpropagation Through Time (BPTT) for a 3-step RNN sequence. Paste the code and briefly describe what each part does.
